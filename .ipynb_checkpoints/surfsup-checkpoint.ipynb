# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %%
#Pick Dates for Trip
start_date = dt.date(2020, 2, 12)
end_date = dt.date(2020, 2, 20)

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base=automap_base()

# reflect the tables
Base.prepare(engine, reflect = True)

# %%
# Save references to each table
Station=Base.classes.station
Measurement=Base.classes.measurement

# %%
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['measurement', 'station']

# %%
#check what is in station
inspector = inspect(engine)
columns = inspector.get_columns('station')
for c in columns:
    print(c['name'], c['type'])
# Out:
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
#check what is in measurement
inspector = inspect(engine)
columns = inspector.get_columns('measurement')
for c in columns:
    print(c['name'], c['type'])
# Out:
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT

# %%
# Create our session (link) from Python to the DB
session=Session(engine)

# %% [markdown]
# # Exploratory Climate Analysis

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results
engine.execute("select * from Measurement limit 10").fetchall()
session.query(func.count(Measurement.date)).all()
# Out:
# [(19550)]

# %%
# Calculate the date 1 year ago from the last data point in the database
current_year=session.query(func.max(Measurement.date)).all()
current_year
# Out:
# [('2017-08-23')]

# %%
# Perform a query to retrieve the data and precipitation scores
year_prec = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date >= "2016-08-23").\
        filter(Measurement.date <= "2017-08-23").\
        group_by(Measurement.date).all()
year_prec
# Out:
# [('2016-08-23', 0.0),
#  ('2016-08-24', 0.08),
#  ('2016-08-25', 0.08),
#  ('2016-08-26', 0.0),
#  ('2016-08-27', 0.0),
#  ('2016-08-28', 0.01),
#  ('2016-08-29', 0.0),
#  ('2016-08-30', 0.0),
#  ('2016-08-31', 0.13),
#  ('2016-09-01', 0.0),
#  ('2016-09-02', 0.0),
#  ('2016-09-03', 0.0),
#  ('2016-09-04', 0.03),
#  ('2016-09-05', None),
#  ('2016-09-06', None),
#  ('2016-09-07', 0.05),
#  ('2016-09-08', 0.0),
#  ('2016-09-09', 0.03),
#  ('2016-09-10', 0.0),
#  ('2016-09-11', 0.05),
#  ('2016-09-12', 0.0),
#  ('2016-09-13', 0.02),
#  ('2016-09-14', 1.32),
#  ('2016-09-15', 0.42),
#  ('2016-09-16', 0.06),
#  ('2016-09-17', 0.05),
#  ('2016-09-18', 0.0),
#  ('2016-09-19', 0.0),
#  ('2016-09-20', 0.0),
#  ('2016-09-21', 0.0),
#  ('2016-09-22', 0.02),
#  ('2016-09-23', 0.0),
#  ('2016-09-24', 0.0),
#  ('2016-09-25', 0.0),
#  ('2016-09-26', 0.06),
#  ('2016-09-27', 0.02),
#  ('2016-09-28', 0.0),
#  ('2016-09-29', 0.0),
#  ('2016-09-30', 0.0),
#  ('2016-10-01', 0.0),
# ...

# %%
# Save the query results as a Pandas DataFrame and set the index to the date column
prec_df = pd.DataFrame(val_cal, columns=['date','prcp'])
prec_df
# Out:
#            date  prcp
# 0    2016-08-23  0.00
# 1    2016-08-24  0.08
# 2    2016-08-25  0.08
# 3    2016-08-26  0.00
# 4    2016-08-27  0.00
# ..          ...   ...
# 361  2017-08-19  0.00
# 362  2017-08-20  0.00
# 363  2017-08-21  0.00
# 364  2017-08-22  0.00
# 365  2017-08-23  0.00
#
# [366 rows x 2 columns]

# %%
# Sort the dataframe by date
prec_df.sort_values(by='date',ascending= True)
# Out:
#            date  prcp
# 0    2016-08-23  0.00
# 1    2016-08-24  0.08
# 2    2016-08-25  0.08
# 3    2016-08-26  0.00
# 4    2016-08-27  0.00
# ..          ...   ...
# 361  2017-08-19  0.00
# 362  2017-08-20  0.00
# 363  2017-08-21  0.00
# 364  2017-08-22  0.00
# 365  2017-08-23  0.00
#
# [366 rows x 2 columns]

# %%
# Rename the Columns in the Dataframe
prec_df=prec_df.rename(columns={"date": "Date", "prcp": "Precipitation"})

# %%
#Set Index
prec_df.set_index('Date')
prec_df
# Out:
#            Date  Precipitation
# 0    2016-08-23           0.00
# 1    2016-08-24           0.08
# 2    2016-08-25           0.08
# 3    2016-08-26           0.00
# 4    2016-08-27           0.00
# ..          ...            ...
# 361  2017-08-19           0.00
# 362  2017-08-20           0.00
# 363  2017-08-21           0.00
# 364  2017-08-22           0.00
# 365  2017-08-23           0.00
#
# [366 rows x 2 columns]

# %%
# Use Pandas Plotting with Matplotlib to plot the data
prec_df.plot()
plt.title("Rainfall from 8/23/16 - 8/23/17")
labels = ['tobs']
plt.ylabel('Precipiation Amount', weight='bold')
plt.xlabel('Timeframe', weight='bold')
# Out:
# Text(0.5, 0, 'Timeframe')

# %%
#get statistical analysis
stat=prec_df.describe()
round(stat,2)
# Out:
#        Precipitation
# count         364.00
# mean            0.05
# std             0.20
# min             0.00
# 25%             0.00
# 50%             0.00
# 75%             0.02
# max             2.62

# %%
# Design a query to show how many stations are available in this dataset?

station_count = session.query(func.count(Station.station)).all()
station_count
# Out:
# [(9)]

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.

active_stations = session.query(Measurement.station, func.count(Measurement.station)).group_by(Measurement.station).order_by(func.count(Measurement.station).desc()).all()
active_stations

#Find the most active stations.
active_stations_count =active_stations[0] 
active_stations_count
# Out:
# ('USC00519281', 2772)

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature of the most active station?

temps = session.query(Measurement.station, func.count(Measurement.station)).group_by(Measurement.station).order_by(func.count(Measurement.station).desc()).all()
temps

all_observations = session.query(Measurement.station,func.min(Measurement.tobs), func.max(Measurement.tobs),func.avg(Measurement.tobs)).filter(Measurement.station == active_stations_count[0]).all()
all_observations
# Out:
# [('USC00519281', 54.0, 85.0, 71.66378066378067)]

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram

active_stations_count =active_stations[0] 
active_stations_count

active_stations_temps= session.query(Measurement.tobs).\
                        filter(Measurement.date >= "2016-08-23").\
                       filter(Measurement.station == "USC00519281").all()
active_stations_temps
len(active_stations_temps)

all_temps= [z[0] for z in active_stations_temps]
all_temps
# Out:
# [77.0,
#  77.0,
#  80.0,
#  80.0,
#  75.0,
#  73.0,
#  78.0,
#  77.0,
#  78.0,
#  80.0,
#  80.0,
#  78.0,
#  78.0,
#  78.0,
#  73.0,
#  74.0,
#  80.0,
#  79.0,
#  77.0,
#  80.0,
#  76.0,
#  79.0,
#  75.0,
#  79.0,
#  78.0,
#  79.0,
#  78.0,
#  78.0,
#  76.0,
#  74.0,
#  77.0,
#  78.0,
#  79.0,
#  79.0,
#  77.0,
#  80.0,
#  78.0,
#  78.0,
#  78.0,
#  77.0,
#  79.0,
#  79.0,
#  79.0,
#  79.0,
#  75.0,
#  76.0,
#  73.0,
#  72.0,
#  71.0,
#  77.0,
#  79.0,
#  78.0,
#  79.0,
#  77.0,
#  79.0,
#  77.0,
#  78.0,
#  78.0,
#  78.0,
#  78.0,
#  77.0,
#  74.0,
#  75.0,
#  76.0,
#  73.0,
#  76.0,
#  74.0,
#  77.0,
#  76.0,
#  76.0,
#  74.0,
#  75.0,
#  75.0,
#  75.0,
#  75.0,
#  71.0,
#  63.0,
#  70.0,
#  68.0,
#  67.0,
#  77.0,
#  74.0,
#  77.0,
#  76.0,
#  76.0,
#  75.0,
#  76.0,
#  75.0,
#  73.0,
#  75.0,
#  73.0,
#  75.0,
#  74.0,
#  75.0,
#  74.0,
#  75.0,
#  73.0,
#  75.0,
#  73.0,
#  73.0,
#  74.0,
#  70.0,
#  72.0,
#  70.0,
#  67.0,
#  67.0,
#  69.0,
#  70.0,
#  68.0,
#  69.0,
#  69.0,
# ...

# %%
#plt.hist(all_temps, bins= 12)
plt.hist(all_temps, bins=12, color="red")
plt.title("Temps of Highest Station (12 Month Timeframe)")
labels = ['tobs']
plt.ylabel('Frequency', weight='bold')
plt.xlabel('Temperature', weight='bold')
plt.figure(2)
